# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data_frame=pd.read_csv("C:/Users/3yearb1/Desktop/cs081/ML_datasets/Salary_dataset.csv")
data_frame
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
data_frame.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
# Unnamed: 0         30 non-null int64
# YearsExperience    30 non-null float64
# Salary             30 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 800.0 bytes

# %%
data_frame.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %%
import sklearn
from sklearn.model_selection import train_test_split
train , test = train_test_split(data_frame, test_size = 0.3)
x_train = train.drop('Salary', axis=1)
y_train = train['Salary']

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (21, 2)
# (21,)

# %%
viz_test.scatter(x_train.iloc[:, 1], y_train, color='red')
viz_test.title('Salary VS Experience (data set)')
viz_test.xlabel('Experience')  
viz_test.ylabel('Salary')      
viz_test.show()

# %%
x_test = test.drop('Salary', axis=1)
y_test = test['Salary']
x_test
# Out:
#     Unnamed: 0  YearsExperience
# 5            5              3.0
# 1            1              1.4
# 12          12              4.1
# 0            0              1.2
# 16          16              5.2
# 25          25              9.1
# 3            3              2.1
# 13          13              4.2
# 22          22              8.0

# %%
y_test
# Out:
# 5      56643.0
# 1      46206.0
# 12     56958.0
# 0      39344.0
# 16     66030.0
# 25    105583.0
# 3      43526.0
# 13     57082.0
# 22    101303.0
# Name: Salary, dtype: float64

# %%
from sklearn import neighbors
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline
model = neighbors.KNeighborsRegressor(n_neighbors = 3)
model.fit(x_train, y_train)
pred=model.predict(x_test)
error = sqrt(mean_squared_error(y_test,pred))
pred
# Out:
# array([ 51496.33333333,  45925.        ,  60042.        ,  45925.        ,
#         70713.33333333, 113012.66666667,  45925.        ,  61615.33333333,
#        107173.        ])

# %%
error
# Out:
# 4913.524711082641
